# %%
library(lattice)
library(datasets)
airquality <- transform(airquality, Month=factor(Month))
xyplot(Ozone~Wind|Month,data=airquality,layout = c(5,1))
# Out:
# plot without title

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
str(mpg)
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	234 obs. of  11 variables:
#  $ manufacturer: chr  "audi" "audi" "audi" "audi" ...
#  $ model       : chr  "a4" "a4" "a4" "a4" ...
#  $ displ       : num  1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int  1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int  4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr  "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr  "f" "f" "f" "f" ...
#  $ cty         : int  18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int  29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr  "p" "p" "p" "p" ...
#  $ class       : chr  "compact" "compact" "compact" "compact" ...

# %%
 qplot(displ, hwy, data=mpg, color=drv)
# Out:
# plot without title

# %%
 qplot(displ, hwy, data=mpg,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(hwy,data=mpg,fill=drv,bins=100)
# Out:
# plot without title

# %%
qplot(displ,hwy,data=mpg,facets=.~drv)
# Out:
# plot without title

# %%
qplot(hwy,data=mpg,facets = drv~.,binwidth=3)
# Out:
# plot without title

# %%
qplot(displ, hwy,data=mpg,facets=class~drv,fill=drv)
# Out:
# plot without title

# %%
qplot(hwy,data=mpg,geom="density",color=drv)
# Out:
# plot without title

# %%
qplot(displ,hwy,data=mpg,shape=drv,col=drv)+geom_smooth(method = "lm")
# Out:
# plot without title

# %%
qplot(displ,hwy,data=mpg,facets=.~drv)+geom_smooth(method = "lm")
# Out:
# plot without title

# %%
g <- ggplot(mpg, aes(displ,hwy))
g <- g+geom_point()+geom_smooth(method="lm")+geom_rug()+facet_grid(.~drv)
g
# Out:
# plot without title

# %%
g <- ggplot(mpg, aes(displ,hwy))
g+geom_point(aes(color=drv,,size=cyl))+geom_smooth(method="lm",se=FALSE,color="brown")
# Out:
# plot without title

# %%
d <- data.frame(x=1:100,y=rnorm(100))
d[50,2] <- 100
g <- ggplot(d, aes(x,y))
g+geom_line(size=1.2)+coord_cartesian(ylim=c(-3,3))
# Out:
# plot without title

# %%
library(ggplot2)
# Out:
# Error in str(movies): object 'movies' not found
# Traceback:
#
# 1. str(movies)
